# %%
educators_list = ['Toba', 'Erioluwa', 'Micheal', 'Ajiboye', 'Iyanu']
print(educators_list[0])
# Out:
# Toba

# %%
students_age = [23, 29, 19, 25, 43, 32, 21]

# %%
students_age.reverse()

# %%
students_age
# Out:
# [21, 32, 43, 25, 19, 29, 23]

# %%
educators_list.index('Micheal')
# Out:
# 2

# %%
print(educators_list[0])
# Out:
# Toba

# %%
print(educators_list[0:3])
# Out:
# ['Toba', 'Erioluwa', 'Micheal']

# %%
## Reversing a list shortcut
educators_list[::-1]
# Out:
# ['Iyanu', 'Ajiboye', 'Micheal', 'Erioluwa', 'Toba']

# %%
student_A = {"name":"Ebuka","age":50}
student_B = {"name": "Ajiboye", "age":35}
part_time = dict(time = 'night', value= 9.00)

# %%
student_A["grade"]="A"

# %%
student_A
# Out:
# {'name': 'Ebuka', 'age': 50, 'grade': 'A'}

# %%
student_A["age"] = 30
student_A
# Out:
# {'name': 'Ebuka', 'age': 30, 'grade': 'A'}

# %%
#creating a dict from two lists
new_dict = dict(zip(educators_list, students_age))

# %%
new_dict
# Out:
# {'Toba': 21, 'Erioluwa': 32, 'Micheal': 43, 'Ajiboye': 25, 'Iyanu': 19}

# %%
student_B.values()
# Out:
# dict_values(['Ajiboye', 35])

# %%
student_A.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student_B["grade"]="c"

# %%
student_B
# Out:
# {'name': 'Ajiboye', 'age': 35, 'grade': ['C']}

# %%
student_B.values()
# Out:
# dict_values(['Ajiboye', 35, 'c'])
